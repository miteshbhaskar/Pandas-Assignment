# %%
import pandas as pd
import numpy as np

# %%
# 3. Assign it to a variable called chipo.

chipo = pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv")

# %%
# 4. See the first 10 entries
chipo.head(10)

# %%
# 5. What is the number of observations in the dataset?
len(chipo)

# %%
# 6. What is the number of columns in the dataset?
len(chipo.columns)

# %%
# 7. Print the name of all the columns.
list(chipo.columns)

# %%
# 8. How is the dataset indexed?
chipo.index

# %%
# 9. Which was the most-ordered item?
ms=chipo['item_name'].mode()
ms1=chipo.groupby('item_name')['item_name'].sum()
# print('Mode:-',ms[0])
# print('values:-',ms1)
ms



camp=chipo['item_name'].value_counts()         # -----CampusX----
camp.head(1)

# %%
# 10. For the most-ordered item, how many items were ordered?
ms=chipo['item_name'].value_counts()
# ms1=max(chipo.groupby('item_name')['item_name'].count())
# print('Mode:-',list(ms))
# print('values:-',ms1)
ms.head(1)

# %%
chipo['choice_description'].str.split(",", expand=True)[0]

# %%
# 11. What was the most ordered item in the choice_description column?
desc=chipo['choice_description'].str.replace("[",'').str.replace("]",'').str.split(",", expand=True)[0]
mms=desc.mode()
print(mms)

# %%
# 12. How many items were orderd in total?

total_items = chipo['item_name'].count()
print("Total Orders : ",total_items)

total_dist = chipo['item_name'].unique()
print("Total Distinct Items :", len(total_dist))

# %%
#  13. Turn the item price into a float
floats=chipo['item_price'].str.replace("$",'').astype(float) # ".astype( DataType )" converts items datatypes of columns
# floats

# a. Check the item price type
type(chipo['item_price'][0])

# b. Create a lambda function and change the type of item price
lam = chipo['item_price'].apply(lambda x: float(x.replace("$",'')))

# c. Check the item price type
type(lam[0])

# %%
# 14. How much was the revenue for the period in the dataset?
chipo['item_price']=chipo['item_price'].str.removeprefix("$").astype("float")
chipo["Amount"] = chipo['quantity'] * chipo['item_price']
Total_revenue = sum(chipo['Amount'])
print("Total Revenue : ${}".format(Total_revenue))

# %%
# 15. How many orders were made in the period?
l2= chipo['order_id'].unique()
len(l2)

# %%
# 16. What is the average revenue amount per order?
avg_revenue= np.average(chipo['Amount'])
print("Average Amount : ${}".format(avg_revenue))

# %%
# 17. How many different items are sold?
itms=chipo['item_name'].value_counts()
print(itms)

# %% [markdown]
# # Ex3 - Getting and Knowing your Data

# %%
data = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user",delimiter="|")


# Step 3. Assign it to a variable called users and use the 'user_id' as index
data.set_index("user_id")

# %%
# Step 4. See the first 25 entries
data.head(25)

# %%
# Step 5. See the last 10 entries
data.tail(10)

# %%
# Step 6. What is the number of observations in the dataset?
len(data)

# %%
data.index(1,axis=0)

# %%
# Step 7. What is the number of columns in the dataset?
data.shape[1]

# %%
# Step 8. Print the name of all the columns.
columns=data.columns
columns

# %%
# Step 9. How is the dataset indexed?
data.index

# %%
# Step 10. What is the data type of each column?
data.info()

# %%
# Step 11. Print only the occupation column
data['occupation']

# %%
# Step 12. How many different occupations are in this dataset?
len(data['occupation'].unique())

# %%
# Step 13. What is the most frequent occupation?
data['occupation'].mode()

# %%
# Step 14. Summarize the DataFrame.
data.describe()

# %%
# Step 15. Summarize all the columns
l1=[]
for i in data:
    val=data[i].describe()
    l1.append(val)
pd.DataFrame(l1).T

# %%
# Step 16. Summarize only the occupation column

data['occupation'].describe()

# %%
# Step 17. What is the mean age of users?
np.mean(data['age'])

# %%
# Step 18. What is the age with least occurrence?
bol = data['age'].value_counts().min()
ad=pd.DataFrame(data['age'].value_counts())
ad[ad['age']==bol]

# %% [markdown]
# # Ex-2

# %%
data = pd.read_csv("./Downloads/food.tsv", delimiter = "\t")
data

# %%
# Step 4. See the first 5 entries
data.head(5)

# %%
# Step 5. What is the number of observations in the dataset?
len(data)

# %%
# Step 6. What is the number of columns in the dataset?
data.shape[1]

# %%
# Step 7. Print the name of all the columns.
data.columns

# %%
# Step 8. What is the name of 105th column?
cols=data.columns
cols[105]

# %%
# Step 9. What is the type of the observations of the 105th column?
data.iloc[:,105].dtype

# %%
# Step 10. How is the dataset indexed?
data.index

# %%
# Step 11. What is the product name of the 19th observation?
data["product_name"].iloc[19]

# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %%
# Step 3. Assign it to a variable called chipo.
import pandas as pd

chipo1 = pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv")
chipo1.set_index("order_id")
chipo1['item_price'] = chipo1['item_price'].str.removeprefix("$").astype("float")

# %%
# Step 4. How many products cost more than $10.00?
chipo1[chipo1['item_price'] > 10]

# %%
# Step 5. What is the price of each item?
product_price=pd.DataFrame(chipo1[["item_name","item_price"]])
# product_price.set_index('item_name',inplace=True)
product_price.drop_duplicates('item_name')

# %%
# Step 6. Sort by the name of the item

chipo1.sort_values("item_name")

# %%
# Step 7. What was the quantity of the most expensive item ordered?
chipo1.sort_values("item_price",ascending=False)["quantity"].iloc[0]

# %%
# Step 8. How many times was a Veggie Salad Bowl ordered?
len(chipo1[chipo1["item_name"] == "Veggie Salad Bowl"])

# %%
# Step 9. How many times did someone order more than one Canned Soda?

# Jigar
len(chipo1[chipo1["item_name"]== "Canned Soda"].query(" quantity > 1"))

# Mitesh Dallo
len(chipo1[(chipo1["item_name"]=="Canned Soda") & (chipo1["quantity"] > 1)])

# %% [markdown]
# # Ex2 - Filtering and Sorting Data

# %%
# Step 1. Import the necessary libraries
import pandas as pd
import numpy as np

# %%
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called euro12.
euro12=pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv")

# %%
# Step 4. Select only the Goal column.
pd.DataFrame(euro12["Goals"])

# %%
# Step 5. How many team participated in the Euro2012?
len(euro12.drop_duplicates("Team"))

# %%
# Step 6. What is the number of columns in the dataset?
euro12.shape[1]

# %%
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
discipline = pd.DataFrame(euro12[["Team","Yellow Cards","Red Cards"]])
discipline

# %%
# Step 8. Sort the teams by Red Cards, then to Yellow Cards
euro12.sort_values(["Red Cards","Yellow Cards"])

# %%
# Step 9. Calculate the mean Yellow Cards given per Team
euro12["Yellow Cards"].mean()

# %%
# Step 10. Filter teams that scored more than 6 goals
euro12[euro12["Goals"]>6]

# %%
# Step 11. Select the teams that start with G
euro12[euro12["Team"].str.startswith("G")]

# %%
# Step 12. Select the first 7 columns
euro12.iloc[:,:7]

# %%
# Step 13. Select all columns except the last 3.
euro12.iloc[:,:-3]

# %%
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia

dt=euro12[(euro12["Team"] == "England") | (euro12["Team"]== "Italy") | (euro12["Team"] =="Russia")]
dt[["Team","Shooting Accuracy"]]

# %% [markdown]
# # Fictional Army - Filtering and Sorting

# %%
# Step 1. Import the necessary libraries
import numpy as np
import pandas as pd

# %%
# Step 2. This is the data given as a dictionary

# Create an example dataframe about a fictional army
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks',
 'Nighthawks',
'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts',
 'Scouts', 'Scouts', 'Scouts'],
 'company': ['1st', '1st', '2nd', '2nd', '1st', '1st',
 '2nd', '2nd','1st', '1st', '2nd', '2nd'],
 'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
 'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
 'size': [1045, 957, 1099, 1400, 1592, 1006, 987,
 849,
973, 1005, 1099, 1523],
 'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48,
 435, 63, 345],
 'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
 'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
 'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
 'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine',
 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming',
 'Louisana', 'Georgia']}

# %%
# Step 3. Create a dataframe and assign it to a variable called army.
army=pd.DataFrame(raw_data)
army

# %%
# Step 4. Set the 'origin' colum as the index of the dataframe
army.set_index("origin",inplace=True)

# %%
# Step 5. Print only the column veterans
army["veterans"]

# %%
# Step 6. Print the columns 'veterans' and 'deaths'
army[['veterans' , 'deaths']]

# %%
# Step 7. Print the name of all the columns.
list(army.columns)

# %%
# Step 8. Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska
army[['deaths', 'size' , 'deserters']].loc[["Maine","Alaska"]]

# %%
# Step 9. Select the rows 3 to 7 and the columns 3 to 6.
army.iloc[2:7,2:6]

# %%
# Step 10. Select every row after the fourth row and all columns
army.iloc[4::5,:]

# %%
# Step 11. Select every row up to the 4th row and all columns
army.iloc[:4]

# %%
# Step 12. Select the 3rd column up to the 7th column
army.iloc[:,2:7]

# %%
# Step 13. Select rows where df.deaths is greater than 50
army[army["deaths"] > 50]

# %%
# Step 14. Select rows where df.deaths is greater than 500 or less than 50
army[(army["deaths"]< 50) | (army["deaths"] > 500)]

# %%
# Step 15. Select all the regiments not named "Dragoons"
army[army["regiment"] != "Dragoons"]

# %%
# Step 16. Select the rows called Texas and Arizona
army.loc[["Texas","Arizona"]]

# %%
# Step 17. Select the third cell in the row named Arizona
army.loc["Arizona"][2]

# %%
# Step 18. Select the third cell down in the column named deaths
army["deaths"][2]

# %% [markdown]
# # Ex - GroupBy

# %%
# Step 1. Import the necessary libraries
import pandas as pd
import numpy as np

# %%
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called drinks.
drinks=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv")
drinks

# %%
# Step 4. Which continent drinks more beer on average?
avg=drinks.groupby("continent")["beer_servings"].mean().idxmax()
avg

# %%
# Step 5. For each continent print the statistics for wine consumption.
drinks.groupby("continent")["wine_servings"].describe()

# %%
# Step 6. Print the mean alcohol consumption per continent for every column
drinks.groupby("continent").mean()

# %%
# Step 7. Print the median alcohol consumption per continent for every column
drinks.groupby("continent").median()

# %%
# Step 8. Print the mean, min and max values for spirit consumption.
spirit= pd.DataFrame()
spirit["Mean"]=drinks.groupby("continent")["spirit_servings"].mean()
spirit["Min"]=drinks.groupby("continent")["spirit_servings"].min()
spirit["Max"]=drinks.groupby("continent")["spirit_servings"].max()
spirit

# %% [markdown]
# # Occupation

# %%
# Step 1. Import the necessary libraries
import pandas as pd
import numpy as np

# %%
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called users.
users= pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user",delimiter="|")
users.sample(3)

# %%
# Step 4. Discover what is the mean age per occupation
users.groupby("occupation")["age"].mean()

# %%
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least
m_r = (users[users["gender"]=="M"].groupby("occupation").size())*100 / users.groupby("occupation").size()
m_r.sort_values(ascending=False)

# %%
# Step 6. For each occupation, calculate the minimum and maximum ages
ages = pd.DataFrame()
ages["Min"]=users.groupby("occupation")["age"].min()
ages["Max"]= users.groupby("occupation")["age"].max()
ages

# %%
# Step 7. For each combination of occupation and gender, calculate the mean age
users.groupby(["occupation","gender"])["age"].mean().unstack(1).set_axis(["F","M"],axis=1)

# %%
# Step 8. For each occupation present the percentage of women and men
gender = pd.DataFrame()
gender["Male"]= (users[users["gender"]=="M"].groupby("occupation").size())*100 / users.groupby("occupation").size()
gender["Female"] = (users[users["gender"]=="F"].groupby("occupation").size())*100 / users.groupby("occupation").size()
gender

# %% [markdown]
# # Regiment

# %%
# Step 1. Import the necessary libraries
import pandas as pd
import numpy as np

# %%
# Step 2. Create the DataFrame with the following values
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks',
 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons',
 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
 'company': ['1st', '1st', '2nd', '2nd', '1st', '1st',
 '2nd', '2nd','1st', '1st', '2nd', '2nd'],
 'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze',
 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger',
 'Riani', 'Ali'],
 'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3,
 2, 3],
 'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57,
 62, 70, 62, 70]}

# %%
# Step 3. Assign it to a variable called regiment.
regiment = pd.DataFrame(raw_data)
regiment
# Out:
#       regiment company      name  preTestScore  postTestScore
# 0   Nighthawks     1st    Miller             4             25
# 1   Nighthawks     1st  Jacobson            24             94
# 2   Nighthawks     2nd       Ali            31             57
# 3   Nighthawks     2nd    Milner             2             62
# 4     Dragoons     1st     Cooze             3             70
# 5     Dragoons     1st     Jacon             4             25
# 6     Dragoons     2nd    Ryaner            24             94
# 7     Dragoons     2nd      Sone            31             57
# 8       Scouts     1st     Sloan             2             62
# 9       Scouts     1st     Piger             3             70
# 10      Scouts     2nd     Riani             2             62
# 11      Scouts     2nd       Ali             3             70

# %%
# Step 4. What is the mean preTestScore from the regiment Nighthawks?
regiment[regiment["regiment"] == "Nighthawks"]["preTestScore"].mean()
# Out:
# 15.25

# %%
# Step 5. Present general statistics by company
regiment["company"].describe()
# Out:
# count      12
# unique      2
# top       1st
# freq        6
# Name: company, dtype: object

# %%
# Step 6. What is the mean of each company's preTestScore?
regiment.groupby("company")["preTestScore"].mean()
# Out:
# company
# 1st     6.666667
# 2nd    15.500000
# Name: preTestScore, dtype: float64

# %%
# Step 7. Present the mean preTestScores grouped by regiment cand company
pd.DataFrame(regiment.groupby(["regiment","company"])["preTestScore"].mean().unstack(1).set_axis(["1st","2nd"],axis=1))
# Out:
#              1st   2nd
# regiment
# Dragoons     3.5  27.5
# Nighthawks  14.0  16.5
# Scouts       2.5   2.5

# %%
# Step 8. Present the mean preTestScores grouped by regiment and company without heirarchical indexing
pivot=pd.DataFrame(regiment.groupby(["regiment","company"])["preTestScore"].mean().reset_index())
pivot
# Out:
#      regiment company  preTestScore
# 0    Dragoons     1st           3.5
# 1    Dragoons     2nd          27.5
# 2  Nighthawks     1st          14.0
# 3  Nighthawks     2nd          16.5
# 4      Scouts     1st           2.5
# 5      Scouts     2nd           2.5

# %%
# Step 9. Group the entire dataframe by regiment and company
regiment.groupby(["regiment","company"])[["name","preTestScore","postTestScore"]]

# %%
# Step 10. What is the number of observations in each regiment and company
regiment.groupby(["regiment","company"]).size()
# Out:
# regiment    company
# Dragoons    1st        2
#             2nd        2
# Nighthawks  1st        2
#             2nd        2
# Scouts      1st        2
#             2nd        2
# dtype: int64

# %%
# Step 11. Iterate over a group and print the name and the whole data from the regiment
for i in regiment.groupby("regiment"):
    print(i)
# Out:
# ('Dragoons',    regiment company    name  preTestScore  postTestScore
# 4  Dragoons     1st   Cooze             3             70
# 5  Dragoons     1st   Jacon             4             25
# 6  Dragoons     2nd  Ryaner            24             94
# 7  Dragoons     2nd    Sone            31             57)
# ('Nighthawks',      regiment company      name  preTestScore  postTestScore
# 0  Nighthawks     1st    Miller             4             25
# 1  Nighthawks     1st  Jacobson            24             94
# 2  Nighthawks     2nd       Ali            31             57
# 3  Nighthawks     2nd    Milner             2             62)
# ('Scouts',    regiment company   name  preTestScore  postTestScore
# 8    Scouts     1st  Sloan             2             62
# 9    Scouts     1st  Piger             3             70
# 10   Scouts     2nd  Riani             2             62
# 11   Scouts     2nd    Ali             3             70)

# %% [markdown]
# # Student Alcohol Consumption

# %%
# Step 1. Import the necessary libraries
import pandas as pd
import numpy as np

# %%
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called df.
df= pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
# Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column
df.loc[:,"school" : "guardian"]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian
# 0    course   mother
# ...

# %%
# Step 5. Create a lambda function that will capitalize strings.
capitalize_string = lambda x : x.capitalize()

# %%
# Step 6. Capitalize both Mjob and Fjob
df["Mjob"].apply(capitalize_string)
df["Fjob"].apply(capitalize_string)
# Out:
# 0       Teacher
# 1         Other
# 2         Other
# 3      Services
# 4         Other
#          ...
# 390    Services
# 391    Services
# 392       Other
# 393       Other
# 394     At_home
# Name: Fjob, Length: 395, dtype: object

# %%
# Step 7. Print the last elements of the data set.
df.tail(1)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob     Fjob  ...  \
# 394     MS   M   19       U     LE3       T     1     1  other  at_home  ...
#
#     famrel freetime  goout  Dalc  Walc health absences G1 G2 G3
# 394      3        2      3     3     3      5        5  8  9  9
#
# [1 rows x 33 columns]

# %%
# Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.
df["Mjob"]=df["Mjob"].apply(capitalize_string)
df["Fjob"]=df["Fjob"].apply(capitalize_string)

# %%
# Step 9. Create a function called majority that returns a boolean value to a new column called legal_drinker
#         (Consider majority as older than 17 years old)

def majority(age):
    return age > 17

df["legal_drinker"]= df["age"].apply(lambda x: majority(x))
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  Services  Services
# 391     MS   M   17       U     LE3       T     3     1  Services  Services
# 392     MS   M   21       R     GT3       T     1     1     Other     Other
# 393     MS   M   18       R     LE3       T     3     2  Services     Other
# 394     MS   M   19       U     LE3       T     1     1     Other   At_home
#
# ...

# %%
# # Step 10. Multiply every number of the dataset by 10.

df.applymap(lambda x : x * 10 if isinstance(x,(float,int)) else x )
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F  180       U     GT3       A    40    40   at_home   teacher
# 1       GP   F  170       U     GT3       T    10    10   at_home     other
# 2       GP   F  150       U     LE3       T    10    10   at_home     other
# 3       GP   F  150       U     GT3       T    40    20    health  services
# 4       GP   F  160       U     GT3       T    30    30     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M  200       U     LE3       A    20    20  services  services
# 391     MS   M  170       U     LE3       T    30    10  services  services
# 392     MS   M  210       R     GT3       T    10    10     other     other
# 393     MS   M  180       R     LE3       T    30    20  services     other
# 394     MS   M  190       U     LE3       T    10    10     other   at_home
#
# ...

# %% [markdown]
# # United States - Crime Rates - 1960 - 2014

# %%
# Step 1. Import the necessary libraries
import pandas as pd
import numpy as np

# %%
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called crime.
crime=pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv")
crime.head(5)
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
# Step 4. What is the type of the columns?
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
# Step 5. Convert the type of the column Year to datetime64
crime["Year"] = pd.to_datetime(crime["Year"],format="%Y")
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
# Step 6. Set the Year column as the index of the dataframe
crime.set_index("Year")
# Out:
#       Population     Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960   179323175   3384200   288460   3095700    9110          17190   107840
# 1961   182992000   3488000   289390   3198600    8740          17220   106670
# 1962   185771000   3752200   301510   3450700    8530          17550   110860
# 1963   188483000   4109500   316970   3792500    8640          17650   116470
# 1964   191141000   4564600   364220   4200400    9360          21420   130390
# 1965   193526000   4739400   387390   4352000    9960          23410   138690
# 1966   195576000   5223500   430180   4793300   11040          25820   157990
# 1967   197457000   5903400   499930   5403500   12240          27620   202910
# 1968   199399000   6720200   595010   6125200   13800          31670   262840
# 1969   201385000   7410900   661870   6749000   14760          37170   298850
# 1970   203235298   8098000   738820   7359200   16000          37990   349860
# ...

# %%
# Step 7. Delete the Total column
crime.drop(columns="Total",inplace=True)

# %%
# Step 8. Group the year by decades and sum the values
crime["decade"]=crime["Year"].apply(lambda x: int(x/10) * 10)
# decades=crime.loc[:,"Total":"decade"]
sums=crime.loc[:,"Total":"decade"].groupby("decade").sum()
sums
# Out:
#             Total   Violent   Property  Murder  Forcible_Rape  Robbery  \
# decade
# 1960     49295900   4134930   45160900  106180         236720  1633510
# 1970    100991600   9607930   91383800  192230         554570  4159020
# 1980    131123369  14074328  117048900  206439         865639  5383109
# 1990    136582146  17527048  119053499  211664         998827  5748930
# 2000    115012044  13968056  100944369  163068         922499  4230366
# 2010     50167967   6072017   44095950   72867         421059  1749809
#
#         Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# decade
# 1960               2158520  13321100       26547700        5292100
# 1970               4702120  28486000       53157800        9739900
# 1980               7619130  33073494       72040253       11935411
# 1990              10568963  26750015       77679366       14624418
# 2000               8652124  21565176       67970291       11412834
# ...

# %%
# Step 9. What is the most dangerous decade to live in the US
sums["Total"].idxmax()
# Out:
# 1990

# %% [markdown]
# ## import file through Path
# ### ".."-> 1 previous directory
# ### "." -> current Directory
# Ex:- pd.read_csv("../data/student.csv")

# %%
df = pd.read_csv("C:\\Users\\HP\\OneDrive\\Documents\\Assignments\\data\\student.csv")

# %% [markdown]
# # MPG Cars

# %%
# Step 1. Import the necessary libraries
import pandas as pd
import numpy as np

# %%
# Step 2. Import the first dataset cars1 and cars2.
# Step 3. Assign each to a variable called cars1 and cars2
cars1=pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv")
cars2=pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv")

# %%
cars2.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  33.0          4            91         53    1795          17.4     76
# 1  20.0          6           225        100    3651          17.7     76
# 2  18.0          6           250         78    3574          21.0     76
# 3  18.5          6           250        110    3645          16.2     76
# 4  17.5          6           258         95    3193          17.8     76
#
#    origin                 car
# 0       3         honda civic
# 1       1      dodge aspen se
# 2       1   ford granada ghia
# 3       1  pontiac ventura sj
# 4       1       amc pacer d/l

# %%
# Step 4. Oops, it seems our first dataset has some unnamed blank columns, fix cars1
cars1=cars1.loc[:,"mpg":"car"]
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# Step 5. What is the number of observations in each dataset?
print("Cars1:",len(cars1),", Cars2:",len(cars2))
# Out:
# Cars1: 198 , Cars2: 200

# %%
# Step 6. Join cars1 and cars2 into a single DataFrame called cars
cars = pd.concat([cars1,cars2],ignore_index=True)
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 393  27.0          4           140         86    2790          15.6     82
# 394  44.0          4            97         52    2130          24.6     82
# 395  32.0          4           135         84    2295          11.6     82
# 396  28.0          4           120         79    2625          18.6     82
# 397  31.0          4           119         82    2720          19.4     82
#
#      origin                        car
# ...

# %%
# Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.
owners= np.random.randint(15000,73000,len(cars))
# owners

# %%
# Step 8. Add the column owners to cars
cars["owners"] = owners
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 393  27.0          4           140         86    2790          15.6     82
# 394  44.0          4            97         52    2130          24.6     82
# 395  32.0          4           135         84    2295          11.6     82
# 396  28.0          4           120         79    2625          18.6     82
# 397  31.0          4           119         82    2720          19.4     82
#
#      origin                        car  owners
# ...

# %% [markdown]
# # Fictitious Names

# %%
# Step 1. Import the necessary libraries
import pandas as pd
import numpy as np

# %%
# Step 2. Create the 3 DataFrames based on the following raw data
raw_data_1 = {
 'subject_id': ['1', '2', '3', '4', '5'],
 'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
 'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}
raw_data_2 = {
 'subject_id': ['4', '5', '6', '7', '8'],
 'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
 'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}
raw_data_3 = {
 'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
 'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %%
# Step 3. Assign each to a variable called data1, data2, data3
data1=pd.DataFrame(raw_data_1)
data2=pd.DataFrame(raw_data_2)
data3=pd.DataFrame(raw_data_3)

# %%
# Step 4. Join the two dataframes along rows and assign all_data
all_data = pd.concat([data1,data2],ignore_index=True)
all_data
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 5          4      Billy    Bonder
# 6          5      Brian     Black
# 7          6       Bran   Balwner
# 8          7      Bryce     Brice
# 9          8      Betty    Btisan

# %%
# Step 5. Join the two dataframes along columns and assing to all_data_col
all_data_col= pd.concat([data2,data3],axis=1)
all_data_col
# Out:
#   subject_id first_name last_name subject_id  test_id
# 0          4      Billy    Bonder          1       51
# 1          5      Brian     Black          2       15
# 2          6       Bran   Balwner          3       15
# 3          7      Bryce     Brice          4       61
# 4          8      Betty    Btisan          5       16
# 5        NaN        NaN       NaN          7       14
# 6        NaN        NaN       NaN          8       15
# 7        NaN        NaN       NaN          9        1
# 8        NaN        NaN       NaN         10       61
# 9        NaN        NaN       NaN         11       16

# %%
# Step 6. Print data3
print(data3)
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %%
# Step 7. Merge all_data and data3 along the subject_id value
pd.merge(all_data,data3,on="subject_id")
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15

# %%
# Step 8. Merge only the data that has the same 'subject_id' on both data1 and data2
pd.merge(data1,data2,on="subject_id")
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %%
# Step 9. Merge all values in data1 and data2, with matching records from both sides where available.
pd.merge(data1,data2,on="subject_id")
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %% [markdown]
# # Housing Market

# %%
# Step 1. Import the necessary libraries
import pandas as pd
import numpy as np

# %%
# Step 2. Create 3 differents Series, each of length 100, as follows:
# 1. The first a random number from 1 to 4
# 2. The second a random number from 1 to 3
# 3. The third a random number from 10,000 to 30,000

s1 = np.random.randint(1,4,100)
s2 = np.random.randint(1,3,100)
s3 = np.random.randint(10000,30000,100)

# %%
# Step 3. Let's create a DataFrame by joinning the Series by column
data = {
    "s1": s1,
    "s2" : s2,
    "s3" : s3
}
data=pd.DataFrame(data)

# %%
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
data.set_axis(['bedrs', 'bathrs', 'price_sqr_meter'],axis=1)
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       1       1            29304
# 1       1       1            15953
# 2       3       2            11387
# 3       1       1            13996
# 4       2       2            16370
# ..    ...     ...              ...
# 95      1       2            19201
# 96      2       1            17293
# 97      1       1            18993
# 98      1       1            13981
# 99      2       2            11389
#
# [100 rows x 3 columns]

# %%
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn
big=pd.DataFrame()
big["bigcolumn"] =  pd.DataFrame(pd.concat([data["s1"],data["s2"],data["s3"]]))
big
# Out:
#     bigcolumn
# 0           1
# 1           1
# 2           3
# 3           1
# 4           2
# ..        ...
# 95      19201
# 96      17293
# 97      18993
# 98      13981
# 99      11389
#
# [300 rows x 1 columns]

# %%
# Step 6. Oops, it seems it is going only until index 99. Is it true?
True
# Out:
# True

# %%
# Step 7. Reindex the DataFrame so it goes from 0 to 299
big.reset_index(drop=True)
# Out:
#      bigcolumn
# 0            1
# 1            1
# 2            3
# 3            1
# 4            2
# ..         ...
# 295          1
# 296          2
# 297          1
# 298          1
# 299          2
#
# [300 rows x 1 columns]

# %% [markdown]
# # US - Baby Names

# %%
# Step 1. Import the necessary libraries
import pandas as pd
import numpy as np

# %%
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called baby_names.

# baby_names = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv')

# %%
baby_names
# Out:
#          Unnamed: 0       Id     Name  Year Gender State  Count
# 0             11349    11350     Emma  2004      F    AK     62
# 1             11350    11351  Madison  2004      F    AK     48
# 2             11351    11352   Hannah  2004      F    AK     46
# 3             11352    11353    Grace  2004      F    AK     44
# 4             11353    11354    Emily  2004      F    AK     41
# ...             ...      ...      ...   ...    ...   ...    ...
# 1016390     5647421  5647422     Seth  2014      M    WY      5
# 1016391     5647422  5647423  Spencer  2014      M    WY      5
# 1016392     5647423  5647424     Tyce  2014      M    WY      5
# 1016393     5647424  5647425   Victor  2014      M    WY      5
# 1016394     5647425  5647426   Waylon  2014      M    WY      5
#
# [1016395 rows x 7 columns]

# %%
# Step 4. See the first 10 entries
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %%
# Step 5. Delete the column 'Unnamed: 0' and 'Id
baby_names=baby_names.drop(columns=["Unnamed: 0","Id"])

# %%
# Step 6. Is there more male or female names in the dataset?
baby_names.value_counts("Gender").idxmax()
# Out:
# 'F'

# %%
# Step 7. Group the dataset by name and assign to names
names=baby_names.groupby("Name")

# %%
# Step 8. How many different names exist in the dataset?
len(baby_names["Name"].unique())
# Out:
# 17632

# %%
# Step 9. What is the name with most occurrences?
names.size().idxmax()
# Out:
# 'Riley'

# %%
# Step 10. How many different names have the least occurrences?
# baby_names.value_counts("Name",ascending=True)
sort =pd.DataFrame(baby_names.value_counts('Name',ascending=True))
sort[sort[0]==1]
# Out:
#            0
# Name
# Katherina  1
# Breyona    1
# Greidy     1
# Shriyan    1
# Briah      1
# ...       ..
# Angelea    1
# Jassmine   1
# Uziah      1
# Terique    1
# Lezli      1
#
# [3682 rows x 1 columns]

# %%
# Step 11. What is the median name occurrence?
baby_names.value_counts("Name").median()
# Out:
# 8.0

# %%
# Step 12. What is the standard deviation of names?
baby_names.value_counts("Name").std()
# Out:
# 122.02996350814088

# %%
# Step 13. Get a summary with the mean, min, max, std and quartiles
baby_names.value_counts("Name").describe()[['mean','min','max','25%','50%','75%']]
# Out:
# mean      57.644907
# min        1.000000
# max     1112.000000
# 25%        2.000000
# 50%        8.000000
# 75%       39.000000
# dtype: float64

# %% [markdown]
# # Wind Statistics

# %%
# Step 1. Import the necessary libraries
import pandas as pd
import numpy as np

# %%
# Step 2. Import the dataset from this address

# %%
columns='Yr Mo Dy RPT VAL ROS KIL SHA BIR DUB CLA MUL CLO BEL MAL'  #Method -1
columns=columns.split()
data=pd.read_csv('wind_state.txt',header=None)
data=data.set_axis(['data'],axis=1)
data=data['data'].str.split(expand=True).set_axis(columns,axis=1)

# %%
data=data.iloc[1:,:]

# %%
# ans=[]
# columns=['Yr','Mo','Dy','RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']
# with open('wind_state.txt') as data:
#     for line in data:
#         l=line.split('\t')                                           #Method - 2
#         ans.append(l)

# wind=pd.DataFrame(ans,columns=["Data"])
# wind = wind["Data"].str.split(expand=True)
# wind= wind.iloc[1:,:]
# wind=wind.set_axis([columns],axis=1)
# wind=wind.reset_index(drop=True)

# %%
data[['RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']]=data[['RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']].astype('float')
data[['Yr','Mo','Dy']]=data[['Yr','Mo','Dy']].astype('int')

# %%
# Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.
date_cols = {
    'year': data['Yr'] + 1900,
    'month': data['Mo'],
    'day': data['Dy'] }

data.insert(0,'Date',pd.to_datetime(date_cols))
data.drop(["Yr","Mo","Dy"],axis=1)
data=data.reset_index(drop=True)

# %%
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].
data.set_index("Date")
# Out:
#             Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB  \
# Date
# 1961-01-01  61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67
# 1961-01-02  61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50
# 1961-01-03  61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25
# 1961-01-04  61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63
# 1961-01-05  61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92
# ...         ..  ..  ..    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46
# 1978-12-28  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33
# 1978-12-29  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17
# 1978-12-30  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08
# 1978-12-31  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25
#
#               CLA    MUL    CLO    BEL    MAL
# Date
# ...

# %%
# Step 6. Compute how many values are missing for each location over the entire record.
missing=data.isna().sum().sum()
missing
# Out:
# 31

# %%
# Step 7. Compute how many non-missing values there are in
len(data)-missing
# Out:
# 6543

# %%
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
data.mean().mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5388\2717486995.py:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data.mean().mean()
# 10.227982360836924

# %%
# Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of
#         the windspeeds at each location over all the days
loc_stats = data.describe().loc[["min","max","mean","std"]]
loc_stats
# Out:
#             RPT        VAL        ROS        KIL        SHA        BIR  \
# min    0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
# max   35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# mean  12.362987  10.644314  11.660526   6.306468  10.455834   7.092254
# std    5.618413   5.267356   5.008450   3.605811   4.936125   3.968683
#
#             DUB        CLA        MUL        CLO        BEL        MAL
# min    0.000000   0.000000   0.000000   0.040000   0.130000   0.670000
# max   30.370000  31.080000  25.880000  28.210000  42.380000  42.540000
# mean   9.797343   8.495053   8.493590   8.707332  13.121007  15.599079
# std    4.977555   4.499449   4.166872   4.503954   5.835037   6.699794

# %%
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the
#          windspeeds across all the locations at each day.
day_stats=data.groupby("day").describe().loc[["min","max","mean","std"]]
day_stats

# %%
data.groupby('Dy')[['BIR', 'RPT']].agg(['min', 'max', 'std', 'mean'])
# Out:
#      BIR                              RPT
#      min    max       std      mean   min    max       std       mean
# Dy
# 1   0.37  26.04  4.105684  7.377407  3.42  34.37  5.534959  12.787037
# 2   0.04  22.50  4.036376  7.094583  2.62  33.84  5.946406  12.726713
# 3   0.17  20.21  3.858780  6.748981  2.00  26.30  4.838973  12.264028
# 4   0.00  21.34  3.964232  6.740602  1.21  29.04  5.482379  11.644651
# 5   0.13  19.95  3.666921  7.008148  2.67  28.33  5.018858  11.770972
# 6   0.00  19.50  4.041819  6.857083  2.37  29.33  5.736093  12.353333
# 7   0.08  24.25  4.064026  7.044954  1.50  35.80  5.991000  12.508519
# 8   0.13  19.12  3.812162  6.867685  2.29  32.58  5.355591  12.023935
# 9   0.00  20.67  3.939803  7.345602  2.21  31.42  5.428632  12.517870
# 10  0.00  20.58  4.043949  7.421343  3.33  33.84  5.933813  12.755370
# 11  0.29  19.12  3.983327  7.410185  1.96  30.84  5.759974  13.002605
# 12  0.13  20.58  4.326077  7.394537  2.88  30.91  6.245118  12.884813
# ...

# %%
# Step 11. Find the average windspeed in January for each location.
year=data[data["Date"].dt.year.isin([1961,1962])]
year.groupby(year["Date"].dt.month ==1).mean().iloc[1]
# Out:
# RPT    14.812131
# VAL    12.583934
# ROS    13.011774
# KIL     7.637419
# SHA    11.438000
# BIR     8.654032
# DUB    12.698387
# CLA     9.425574
# MUL     9.377903
# CLO    10.803065
# BEL    15.125161
# MAL    15.182419
# Name: True, dtype: float64

# %%
# Step 12. Downsample the record to a yearly frequency for each location.
# data.groupby(data["Date"].dt.year).
# data.groupby(data["Date"]).resample('Y').first()
# data.set_index('Date',inplace=True)
data.groupby(['RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']).resample('Y').count().iloc[:,0]
# Out:
# RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO    BEL    MAL    Date
# 0.67   3.58   4.17   0.67   4.88   0.21   1.08   2.79   1.54   5.21   2.54   13.21  1969-12-31    1
#        4.50   2.96   0.87   1.38   1.21   3.63   1.54   1.71   1.42   8.67   6.79   1962-12-31    1
# 0.79   6.79   5.88   0.75   1.79   0.96   3.04   0.83   4.46   1.58   6.21   10.88  1978-12-31    1
# 0.96   2.33   4.17   2.21   4.38   3.83   6.42   5.04   5.00   6.46   9.42   13.96  1962-12-31    1
# 1.00   5.09   6.46   1.21   5.25   4.04   2.79   8.08   6.21   7.12   13.50  11.54  1962-12-31    1
#                                                                                                  ..
# 33.84  26.38  28.16  18.41  24.25  22.50  25.04  20.79  19.92  20.96  24.21  33.63  1972-12-31    1
#        26.92  24.41  20.08  23.75  20.58  20.21  18.71  21.92  22.75  23.09  27.58  1977-12-31    1
# ...

# %%
# Step 13. Downsample the record to a monthly frequency for each location.
data.groupby(['RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']).resample('M').count().iloc[:,0]
# Out:
# RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO    BEL    MAL    Date
# 0.67   3.58   4.17   0.67   4.88   0.21   1.08   2.79   1.54   5.21   2.54   13.21  1969-02-28    1
#        4.50   2.96   0.87   1.38   1.21   3.63   1.54   1.71   1.42   8.67   6.79   1962-01-31    1
# 0.79   6.79   5.88   0.75   1.79   0.96   3.04   0.83   4.46   1.58   6.21   10.88  1978-09-30    1
# 0.96   2.33   4.17   2.21   4.38   3.83   6.42   5.04   5.00   6.46   9.42   13.96  1962-08-31    1
# 1.00   5.09   6.46   1.21   5.25   4.04   2.79   8.08   6.21   7.12   13.50  11.54  1962-06-30    1
#                                                                                                  ..
# 33.84  26.38  28.16  18.41  24.25  22.50  25.04  20.79  19.92  20.96  24.21  33.63  1972-02-29    1
#        26.92  24.41  20.08  23.75  20.58  20.21  18.71  21.92  22.75  23.09  27.58  1977-03-31    1
# ...

# %%
# Step 14. Downsample the record to a weekly frequency for each location.
data.groupby("Date").resample('W').mean()
# Out:
#                          Yr    Mo    Dy    RPT    VAL    ROS    KIL    SHA  \
# Date       Date
# 1961-01-01 1961-01-01  61.0   1.0   1.0  15.04  14.96  13.17   9.29    NaN
# 1961-01-02 1961-01-08  61.0   1.0   2.0  14.71    NaN  10.83   6.50  12.62
# 1961-01-03 1961-01-08  61.0   1.0   3.0  18.50  16.88  12.33  10.13  11.17
# 1961-01-04 1961-01-08  61.0   1.0   4.0  10.58   6.63  11.75   4.58   4.54
# 1961-01-05 1961-01-08  61.0   1.0   5.0  13.33  13.25  11.42   6.17  10.71
# ...                     ...   ...   ...    ...    ...    ...    ...    ...
# 1978-12-27 1978-12-31  78.0  12.0  27.0  17.58  16.96  17.62   8.08  13.21
# 1978-12-28 1978-12-31  78.0  12.0  28.0  13.21   5.46  13.46   5.00   8.12
# 1978-12-29 1978-12-31  78.0  12.0  29.0  14.00  10.29  14.42   8.71   9.71
# 1978-12-30 1978-12-31  78.0  12.0  30.0  18.50  14.04  21.29   9.13  12.75
# 1978-12-31 1978-12-31  78.0  12.0  31.0  20.33  17.41  27.29   9.59  12.08
#
# ...

# %%
# Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for
#          each week (assume that the first week starts on January 2 1961) for the first 52 weeks.
ans=data.groupby(data['Date'].dt.week)[['RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']].describe()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15464\89234074.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   ans=data.groupby(data['Date'].dt.week)[['RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']].describe()
